# %%
#import pandas library
import pandas as pd

# %%
#load dataset
df=pd.read_csv("intern/01.Data Cleaning and Preprocessing.csv")
df
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0           NaN    23.10    16.520     121.717  1177.607      169.805
# 1           NaN    27.60    16.810      79.022  1328.360      341.327
# 2           NaN    23.19    16.709      79.562  1329.407      239.161
# 3           NaN    23.60    16.478      81.011  1334.877      213.527
# 4           NaN    22.90    15.618      93.244  1334.168      243.131
# ..          ...      ...       ...         ...       ...          ...
# 296    12-09:00    20.90    15.167      84.640  1283.706      339.440
# 297    12-10:00    24.98       NaN      85.034  1278.345      368.564
# 298    12-11:00    21.00       NaN      88.013  1307.722      278.842
# 299    12-12:00    21.40       NaN      85.490  1255.986      273.484
# 300    31-05:00    20.89    14.308      94.172  1327.832      251.120
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
#calculate the info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Observation      291 non-null    object
#  1   Y-Kappa          301 non-null    float64
#  2   ChipRate         297 non-null    float64
#  3   BF-CMratio       287 non-null    float64
#  4   BlowFlow         288 non-null    float64
#  5   ChipLevel4       300 non-null    float64
#  6   T-upperExt-2     300 non-null    float64
#  7   T-lowerExt-2     300 non-null    float64
#  8   UCZAA            277 non-null    float64
#  9   WhiteFlow-4      300 non-null    float64
#  10  AAWhiteSt-4      160 non-null    float64
#  11  AA-Wood-4        300 non-null    float64
#  12  ChipMoisture-4   300 non-null    float64
#  13  SteamFlow-4      300 non-null    float64
#  14  Lower-HeatT-3    300 non-null    float64
#  15  Upper-HeatT-3    300 non-null    float64
# ...

# %%
#caculating the sum
df.isnull().sum()
# Out:
# Observation         10
# Y-Kappa              0
# ChipRate             4
# BF-CMratio          14
# BlowFlow            13
# ChipLevel4           1
# T-upperExt-2         1
# T-lowerExt-2         1
# UCZAA               24
# WhiteFlow-4          1
# AAWhiteSt-4        141
# AA-Wood-4            1
# ChipMoisture-4       1
# SteamFlow-4          1
# Lower-HeatT-3        1
# Upper-HeatT-3        1
# ChipMass-4           1
# WeakLiquorF          1
# BlackFlow-2          1
# WeakWashF            1
# SteamHeatF-3         1
# T-Top-Chips-4        1
# SulphidityL-4      141
# dtype: int64

# %%
#calculating the duplicates
duplicates=df[df.duplicated()]
duplicates
len(duplicates)
# Out:
# 0

# %%
#calculating the shape
df.shape
# Out:
# (301, 23)

# %%
df=df.drop_duplicates()
df.shape
# Out:
# (301, 23)

# %%
#calculating the duplicates
duplicates=df[df.duplicated()]
duplicates
len(duplicates)
# Out:
# 0

# %%
df.iloc[0:10,0]=None
df.info
# Out:
# <bound method DataFrame.info of     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0          None    23.10    16.520     121.717  1177.607      169.805
# 1          None    27.60    16.810      79.022  1328.360      341.327
# 2          None    23.19    16.709      79.562  1329.407      239.161
# 3          None    23.60    16.478      81.011  1334.877      213.527
# 4          None    22.90    15.618      93.244  1334.168      243.131
# ..          ...      ...       ...         ...       ...          ...
# 296    12-09:00    20.90    15.167      84.640  1283.706      339.440
# 297    12-10:00    24.98       NaN      85.034  1278.345      368.564
# 298    12-11:00    21.00       NaN      88.013  1307.722      278.842
# 299    12-12:00    21.40       NaN      85.490  1255.986      273.484
# 300    31-05:00    20.89    14.308      94.172  1327.832      251.120
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Observation      291 non-null    object
#  1   Y-Kappa          301 non-null    float64
#  2   ChipRate         297 non-null    float64
#  3   BF-CMratio       287 non-null    float64
#  4   BlowFlow         288 non-null    float64
#  5   ChipLevel4       300 non-null    float64
#  6   T-upperExt-2     300 non-null    float64
#  7   T-lowerExt-2     300 non-null    float64
#  8   UCZAA            277 non-null    float64
#  9   WhiteFlow-4      300 non-null    float64
#  10  AAWhiteSt-4      160 non-null    float64
#  11  AA-Wood-4        300 non-null    float64
#  12  ChipMoisture-4   300 non-null    float64
#  13  SteamFlow-4      300 non-null    float64
#  14  Lower-HeatT-3    300 non-null    float64
#  15  Upper-HeatT-3    300 non-null    float64
# ...

# %%
df.to_csv("intern/01.Data Cleaning and Preprocessing.csv",index=False)
